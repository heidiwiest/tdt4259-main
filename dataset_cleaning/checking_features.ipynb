# %%
import pandas as pd
import gzip
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate

# %%
names = ['calendar', 'listings', 'reviews']
dataframes = {}

for name in names:
    # Define the file path
    file_path = '../data/' + name + '.csv.gz'
    # Use gzip.open to decompress the file and then read it with Pandas
    with gzip.open(file_path, 'rt', encoding='utf-8') as file:
        data = pd.read_csv(file)

    dataframes[name] = data

# %%
calendar = dataframes['calendar']
listings = dataframes['listings']
reviews = dataframes['reviews']

# %%
pd.set_option('display.max_columns', None)
listings.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0   9630344   https://www.airbnb.com/rooms/9630344  20231001204715
# 1   3533741   https://www.airbnb.com/rooms/3533741  20231001204715
# 2   9731039   https://www.airbnb.com/rooms/9731039  20231001204715
# 3  21736164  https://www.airbnb.com/rooms/21736164  20231001204715
# 4  22280002  https://www.airbnb.com/rooms/22280002  20231001204715
#
#   last_scraped           source  \
# 0   2023-10-02      city scrape
# 1   2023-10-02  previous scrape
# 2   2023-10-02  previous scrape
# 3   2023-10-02  previous scrape
# 4   2023-10-01      city scrape
#
#                                                 name  \
# 0  Rental unit in Brooklyn  · ★4.80 · 1 bedroom ·...
# 1  Rental unit in New York · 1 bedroom · 1 bed · ...
# 2    Rental unit in Queens · Studio · 1 bed · 1 bath
# 3  Rental unit in Brooklyn · 1 bedroom · 1 bed · ...
# 4  Rental unit in Brooklyn · ★4.98 · 1 bedroom · ...
#
#                                          description  \
# 0  Enjoy your own private bedroom in our 2 bedroo...
# 1  Come stay in the heart of historic Hells Kitch...
# 2  Studio Apartment in the heart of Sunnyside: of...
# 3  Light-filled, high-ceilinged 1BR brownstone ap...
# 4  This is a comfortable super spacious sunny 1 b...
#
#                                neighborhood_overview  \
# 0       Easy access to subway. Trendy and yet quiet.
# 1                                                NaN
# 2                                                NaN
# 3  The neighborhood is vibrant, multicultural, an...
# 4  Welcome to the enchanting neighborhood of Stuy...
#
#                                          picture_url   host_id  \
# 0  https://a0.muscache.com/pictures/496cf3f1-7d0d...  47783628
# 1  https://a0.muscache.com/pictures/45157664/862a...  17791294
# 2  https://a0.muscache.com/pictures/81a96b92-d357...  50213378
# 3  https://a0.muscache.com/pictures/4e3ee5e2-baa1...   4298654
# 4  https://a0.muscache.com/pictures/b187bce7-ded7...  67373899
#
#                                      host_url  host_name  host_since  \
# 0  https://www.airbnb.com/users/show/47783628  Tiffannie  2015-10-30
# 1  https://www.airbnb.com/users/show/17791294     Taylor  2014-07-07
# 2  https://www.airbnb.com/users/show/50213378       Mark  2015-11-30
# 3   https://www.airbnb.com/users/show/4298654        Sam  2012-12-01
# 4  https://www.airbnb.com/users/show/67373899       Will  2016-04-15
#
#   host_location                                        host_about  \
# 0  New York, NY                                               NaN
# 1  New York, NY                                               NaN
# 2  New York, NY                                               NaN
# 3  New York, NY  Lawyer / musician / appreciator of native ferns.
# 4  New York, NY                                     Globetrotter.
#
#   host_response_time host_response_rate host_acceptance_rate  \
# 0                NaN                NaN                  NaN
# 1                NaN                NaN                  NaN
# 2                NaN                NaN                  NaN
# 3                NaN                NaN                  NaN
# 4                NaN                NaN                 100%
#
#   host_is_superhost                                 host_thumbnail_url  \
# 0                 f  https://a0.muscache.com/im/pictures/user/5c087...
# 1                 f  https://a0.muscache.com/im/pictures/user/e204b...
# 2                 f  https://a0.muscache.com/im/pictures/user/65d77...
# 3                 f  https://a0.muscache.com/im/users/4298654/profi...
# 4                 t  https://a0.muscache.com/im/pictures/user/41ec9...
#
#                                     host_picture_url  host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/user/5c087...                 NaN
# 1  https://a0.muscache.com/im/pictures/user/e204b...      Hell's Kitchen
# 2  https://a0.muscache.com/im/pictures/user/65d77...           Sunnyside
# 3  https://a0.muscache.com/im/users/4298654/profi...  Bedford-Stuyvesant
# 4  https://a0.muscache.com/im/pictures/user/41ec9...  Bedford-Stuyvesant
#
#    host_listings_count  host_total_listings_count  \
# 0                  1.0                        2.0
# 1                  1.0                        1.0
# 2                  1.0                        1.0
# 3                  1.0                        2.0
# 4                  1.0                        1.0
#
#                  host_verifications host_has_profile_pic  \
# 0                ['email', 'phone']                    t
# 1                ['email', 'phone']                    t
# 2                ['email', 'phone']                    t
# 3  ['email', 'phone', 'work_email']                    t
# 4                ['email', 'phone']                    t
#
#   host_identity_verified                       neighbourhood  \
# 0                      f  Brooklyn , New York, United States
# 1                      t                                 NaN
# 2                      f                                 NaN
# 3                      t   Brooklyn, New York, United States
# 4                      t   Brooklyn, New York, United States
#
#   neighbourhood_cleansed neighbourhood_group_cleansed  latitude  longitude  \
# 0               Bushwick                     Brooklyn  40.68457  -73.91181
# 1         Hell's Kitchen                    Manhattan  40.76878  -73.98719
# 2              Sunnyside                       Queens  40.74343  -73.91865
# 3     Bedford-Stuyvesant                     Brooklyn  40.68180  -73.93121
# 4     Bedford-Stuyvesant                     Brooklyn  40.68209  -73.94279
#
#                  property_type        room_type  accommodates  bathrooms  \
# 0  Private room in rental unit     Private room             1        NaN
# 1  Private room in rental unit     Private room             2        NaN
# 2           Entire rental unit  Entire home/apt             1        NaN
# 3           Entire rental unit  Entire home/apt             2        NaN
# 4           Entire rental unit  Entire home/apt             4        NaN
#
#   bathrooms_text  bedrooms  beds  \
# 0  1 shared bath       NaN   1.0
# 1         1 bath       1.0   1.0
# 2         1 bath       NaN   1.0
# 3         1 bath       1.0   1.0
# 4         1 bath       1.0   2.0
#
#                                            amenities    price  minimum_nights  \
# 0  ["Body soap", "Dryer", "Refrigerator", "Wifi",...   $65.00              30
# 1  ["Smoke alarm", "Kitchen", "Air conditioning",...  $110.00              30
# 2  ["Smoke alarm", "Kitchen", "Washer", "TV", "Ai...   $99.00              30
# 3  ["Smoke alarm", "Kitchen", "Shampoo", "Long te...   $70.00              45
# 4  ["Clothing storage: closet and dresser", "Micr...  $170.00              30
#
#    maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0              30                      30                      30
# 1            1125                      30                      30
# 2            1125                      30                      30
# 3            1125                      45                      45
# 4             180                      30                      30
#
#    minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                      30                      30                    30.0
# 1                    1125                    1125                    30.0
# 2                    1125                    1125                    30.0
# 3                    1125                    1125                    45.0
# 4                    1125                    1125                    30.0
#
#    maximum_nights_avg_ntm  calendar_updated has_availability  availability_30  \
# 0                    30.0               NaN                t               29
# 1                  1125.0               NaN                f                0
# 2                  1125.0               NaN                t                0
# 3                  1125.0               NaN                t                0
# 4                  1125.0               NaN                t                3
#
#    availability_60  availability_90  availability_365 calendar_last_scraped  \
# 0               59               89               364            2023-10-02
# 1                0                0                 0            2023-10-02
# 2                0                0                 0            2023-10-02
# 3                0                0                 0            2023-10-02
# 4               20               35                96            2023-10-01
#
#    number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# 0                  5                      0                       0
# 1                  0                      0                       0
# 2                  0                      0                       0
# 3                  2                      0                       0
# 4                 88                     14                       0
#
#   first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0   2016-08-14  2018-04-30                  4.80                     4.6
# 1          NaN         NaN                   NaN                     NaN
# 2          NaN         NaN                   NaN                     NaN
# 3   2018-01-07  2019-01-20                  5.00                     5.0
# 4   2017-12-30  2023-06-20                  4.98                     5.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       5.00                   5.00
# 1                        NaN                    NaN
# 2                        NaN                    NaN
# 3                       5.00                   5.00
# 4                       4.99                   4.95
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         5.00                    4.80                 5.00
# 1                          NaN                     NaN                  NaN
# 2                          NaN                     NaN                  NaN
# 3                         5.00                    5.00                 5.00
# 4                         4.91                    4.94                 4.92
#
#   license instant_bookable  calculated_host_listings_count  \
# 0     NaN                f                               1
# 1     NaN                f                               1
# 2     NaN                f                               1
# 3     NaN                f                               1
# 4     NaN                f                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            0
# 2                                            1
# 3                                            1
# 4                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             1
# 1                                             1
# 2                                             0
# 3                                             0
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.06
# 1                                            0                NaN
# 2                                            0                NaN
# 3                                            0               0.03
# 4                                            0               1.26

# %%
listings["host_about"].unique()
# Out:
# array([nan, 'Lawyer / musician / appreciator of native ferns.',
#        'Globetrotter.', ...,
#        'Alan is the Host in New York City.     We also run a Test Prep company based in New York:   City Test Prep is where we can be found.',
#        'Hello! My name is Claudina I am from the island of St Lucia.  I am a friendly honest person who love to meet people of all races.  I love to travel, cook and eat.  ',
#        'Yesim and I are longtime residents of Manhattan’s upper West Side, Yesim is originally from Istanbul and I’m a native New Yorker.  We’re a very easy going, flexible, respectful and outgoing couple and our interests include, but are not limited to, sports and fitness, cycling, gardening, theater, sailing, animals, travel and continuing educational and cultural pursuits.'],
#       dtype=object)

# %%
listings.loc[listings["id"] == 4204302]
# Out:
#            id                           listing_url       scrape_id  \
# 3047  4204302  https://www.airbnb.com/rooms/4204302  20231001204715
#
#      last_scraped           source  \
# 3047   2023-10-02  previous scrape
#
#                                                    name  \
# 3047  Rental unit in New York · 1 bedroom · 1 bed · ...
#
#                                             description  \
# 3047  A lovely clean, 1 bedroom in a prime location ...
#
#                                   neighborhood_overview  \
# 3047  I love being close to Washington square park w...
#
#                                             picture_url   host_id  \
# 3047  https://a0.muscache.com/pictures/94491242/e4b5...  17550546
#
#                                         host_url  host_name  host_since  \
# 3047  https://www.airbnb.com/users/show/17550546  Genevieve  2014-07-02
#
#      host_location host_about host_response_time host_response_rate  \
# 3047  New York, NY        NaN                NaN                NaN
#
#      host_acceptance_rate host_is_superhost  \
# 3047                  NaN                 f
#
#                                      host_thumbnail_url  \
# 3047  https://a0.muscache.com/im/users/17550546/prof...
#
#                                        host_picture_url host_neighbourhood  \
# 3047  https://a0.muscache.com/im/users/17550546/prof...                NaN
#
#       host_listings_count  host_total_listings_count  host_verifications  \
# 3047                  1.0                        1.0  ['email', 'phone']
#
#      host_has_profile_pic host_identity_verified            neighbourhood  \
# 3047                    t                      t  New York, United States
#
#      neighbourhood_cleansed neighbourhood_group_cleansed  latitude  longitude  \
# 3047      Greenwich Village                    Manhattan  40.73293  -73.99782
#
#            property_type        room_type  accommodates  bathrooms  \
# 3047  Entire rental unit  Entire home/apt             3        NaN
#
#      bathrooms_text  bedrooms  beds  \
# 3047         1 bath       1.0   1.0
#
#                                               amenities    price  \
# 3047  ["Kitchen", "Shampoo", "Essentials", "Air cond...  $180.00
#
#       minimum_nights  maximum_nights  minimum_minimum_nights  \
# 3047            1250            1250                    1250
#
#       maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 3047                    1250                    1250                    1250
#
#       minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 3047                  1250.0                  1250.0               NaN
#
#      has_availability  availability_30  availability_60  availability_90  \
# 3047                f                0                0                0
#
#       availability_365 calendar_last_scraped  number_of_reviews  \
# 3047                 0            2023-10-02                  2
#
#       number_of_reviews_ltm  number_of_reviews_l30d first_review last_review  \
# 3047                      0                       0   2014-10-19  2014-11-09
#
#       review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 3047                   3.5                     4.0                        3.0
#
#       review_scores_checkin  review_scores_communication  \
# 3047                    4.0                          4.0
#
#       review_scores_location  review_scores_value license instant_bookable  \
# 3047                     4.5                  4.0     NaN                f
#
#       calculated_host_listings_count  \
# 3047                               1
#
#       calculated_host_listings_count_entire_homes  \
# 3047                                            1
#
#       calculated_host_listings_count_private_rooms  \
# 3047                                             0
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month
# 3047                                            0               0.02

# %% [markdown]
# ### Find unique values and types

# %% [markdown]
# ###### There are 38 792 rows in the dataset and each of the rows have a unique id and listing_url.
#
# ###### Name attribute gives information of location, number of bedrooms, number of beds and number of baths. Sometimes it also gives the number of stars.

# %%
# Get the number of unique values in each column
unique_counts = listings.nunique()

# Convert the unique_counts Series to a DataFrame for formatting
unique_counts_df = unique_counts.reset_index()
unique_counts_df.columns = ['Column', 'Unique Counts']

# Print the unique_counts as a nicely formatted table
print(tabulate(unique_counts_df, headers='keys', tablefmt='pretty'))
# Out:
# +----+----------------------------------------------+---------------+
# |    |                    Column                    | Unique Counts |
# +----+----------------------------------------------+---------------+
# | 0  |                      id                      |     38792     |
# | 1  |                 listing_url                  |     38792     |
# | 2  |                  scrape_id                   |       1       |
# | 3  |                 last_scraped                 |       2       |
# | 4  |                    source                    |       2       |
# | 5  |                     name                     |     12050     |
# | 6  |                 description                  |     34050     |
# | 7  |            neighborhood_overview             |     16917     |
# | 8  |                 picture_url                  |     37938     |
# | 9  |                   host_id                    |     23811     |
# | 10 |                   host_url                   |     23811     |
# | 11 |                  host_name                   |     8828      |
# | 12 |                  host_since                  |     4842      |
# | 13 |                host_location                 |     1022      |
# | 14 |                  host_about                  |     12394     |
# | 15 |              host_response_time              |       4       |
# | 16 |              host_response_rate              |      80       |
# | 17 |             host_acceptance_rate             |      99       |
# | 18 |              host_is_superhost               |       2       |
# | 19 |              host_thumbnail_url              |     23307     |
# | 20 |               host_picture_url               |     23307     |
# | 21 |              host_neighbourhood              |      525      |
# | 22 |             host_listings_count              |      114      |
# | 23 |          host_total_listings_count           |      137      |
# | 24 |              host_verifications              |       7       |
# | 25 |             host_has_profile_pic             |       2       |
# | 26 |            host_identity_verified            |       2       |
# | 27 |                neighbourhood                 |      174      |
# | 28 |            neighbourhood_cleansed            |      223      |
# | 29 |         neighbourhood_group_cleansed         |       5       |
# | 30 |                   latitude                   |     23362     |
# | 31 |                  longitude                   |     21020     |
# | 32 |                property_type                 |      81       |
# | 33 |                  room_type                   |       4       |
# | 34 |                 accommodates                 |      16       |
# | 35 |                  bathrooms                   |       0       |
# | 36 |                bathrooms_text                |      32       |
# | 37 |                   bedrooms                   |      15       |
# | 38 |                     beds                     |      19       |
# | 39 |                  amenities                   |     32035     |
# | 40 |                    price                     |     1184      |
# | 41 |                minimum_nights                |      114      |
# | 42 |                maximum_nights                |      256      |
# | 43 |            minimum_minimum_nights            |      121      |
# | 44 |            maximum_minimum_nights            |      122      |
# | 45 |            minimum_maximum_nights            |      232      |
# | 46 |            maximum_maximum_nights            |      236      |
# | 47 |            minimum_nights_avg_ntm            |      360      |
# | 48 |            maximum_nights_avg_ntm            |      908      |
# | 49 |               calendar_updated               |       0       |
# | 50 |               has_availability               |       2       |
# | 51 |               availability_30                |      31       |
# | 52 |               availability_60                |      61       |
# | 53 |               availability_90                |      91       |
# | 54 |               availability_365               |      366      |
# | 55 |            calendar_last_scraped             |       2       |
# | 56 |              number_of_reviews               |      465      |
# | 57 |            number_of_reviews_ltm             |      144      |
# | 58 |            number_of_reviews_l30d            |      26       |
# | 59 |                 first_review                 |     3962      |
# | 60 |                 last_review                  |     2924      |
# | 61 |             review_scores_rating             |      161      |
# | 62 |            review_scores_accuracy            |      159      |
# | 63 |          review_scores_cleanliness           |      193      |
# | 64 |            review_scores_checkin             |      135      |
# | 65 |         review_scores_communication          |      146      |
# | 66 |            review_scores_location            |      161      |
# | 67 |             review_scores_value              |      165      |
# | 68 |                   license                    |      278      |
# | 69 |               instant_bookable               |       2       |
# | 70 |        calculated_host_listings_count        |      70       |
# | 71 | calculated_host_listings_count_entire_homes  |      56       |
# | 72 | calculated_host_listings_count_private_rooms |      43       |
# | 73 | calculated_host_listings_count_shared_rooms  |       8       |
# | 74 |              reviews_per_month               |      822      |
# +----+----------------------------------------------+---------------+

# %% [markdown]
# ### NaN values

# %%
# Get the missing data counts
missing_data = listings.isna().sum()

# Convert the missing_data Series to a DataFrame for formatting
missing_data_df = missing_data.reset_index()
missing_data_df.columns = ['Column', 'Missing Count']

# Print the missing data counts as a nicely formatted table
print(tabulate(missing_data_df, headers='keys', tablefmt='pretty'))
# Out:
# +----+----------------------------------------------+---------------+
# |    |                    Column                    | Missing Count |
# +----+----------------------------------------------+---------------+
# | 0  |                      id                      |       0       |
# | 1  |                 listing_url                  |       0       |
# | 2  |                  scrape_id                   |       0       |
# | 3  |                 last_scraped                 |       0       |
# | 4  |                    source                    |       0       |
# | 5  |                     name                     |       0       |
# | 6  |                 description                  |      569      |
# | 7  |            neighborhood_overview             |     16236     |
# | 8  |                 picture_url                  |       0       |
# | 9  |                   host_id                    |       0       |
# | 10 |                   host_url                   |       0       |
# | 11 |                  host_name                   |       5       |
# | 12 |                  host_since                  |       5       |
# | 13 |                host_location                 |     8277      |
# | 14 |                  host_about                  |     17149     |
# | 15 |              host_response_time              |     13174     |
# | 16 |              host_response_rate              |     13174     |
# | 17 |             host_acceptance_rate             |     11904     |
# | 18 |              host_is_superhost               |      255      |
# | 19 |              host_thumbnail_url              |       5       |
# | 20 |               host_picture_url               |       5       |
# | 21 |              host_neighbourhood              |     7752      |
# | 22 |             host_listings_count              |       5       |
# | 23 |          host_total_listings_count           |       5       |
# | 24 |              host_verifications              |       5       |
# | 25 |             host_has_profile_pic             |       5       |
# | 26 |            host_identity_verified            |       5       |
# | 27 |                neighbourhood                 |     16235     |
# | 28 |            neighbourhood_cleansed            |       0       |
# | 29 |         neighbourhood_group_cleansed         |       0       |
# | 30 |                   latitude                   |       0       |
# | 31 |                  longitude                   |       0       |
# | 32 |                property_type                 |       0       |
# | 33 |                  room_type                   |       0       |
# | 34 |                 accommodates                 |       0       |
# | 35 |                  bathrooms                   |     38792     |
# | 36 |                bathrooms_text                |      42       |
# | 37 |                   bedrooms                   |     16900     |
# | 38 |                     beds                     |      663      |
# | 39 |                  amenities                   |       0       |
# | 40 |                    price                     |       0       |
# | 41 |                minimum_nights                |       0       |
# | 42 |                maximum_nights                |       0       |
# | 43 |            minimum_minimum_nights            |       0       |
# | 44 |            maximum_minimum_nights            |       0       |
# | 45 |            minimum_maximum_nights            |       0       |
# | 46 |            maximum_maximum_nights            |       0       |
# | 47 |            minimum_nights_avg_ntm            |       0       |
# | 48 |            maximum_nights_avg_ntm            |       0       |
# | 49 |               calendar_updated               |     38792     |
# | 50 |               has_availability               |       0       |
# | 51 |               availability_30                |       0       |
# | 52 |               availability_60                |       0       |
# | 53 |               availability_90                |       0       |
# | 54 |               availability_365               |       0       |
# | 55 |            calendar_last_scraped             |       0       |
# | 56 |              number_of_reviews               |       0       |
# | 57 |            number_of_reviews_ltm             |       0       |
# | 58 |            number_of_reviews_l30d            |       0       |
# | 59 |                 first_review                 |     10352     |
# | 60 |                 last_review                  |     10352     |
# | 61 |             review_scores_rating             |     10347     |
# | 62 |            review_scores_accuracy            |     10762     |
# | 63 |          review_scores_cleanliness           |     10752     |
# | 64 |            review_scores_checkin             |     10766     |
# | 65 |         review_scores_communication          |     10758     |
# | 66 |            review_scores_location            |     10769     |
# | 67 |             review_scores_value              |     10768     |
# | 68 |                   license                    |     35853     |
# | 69 |               instant_bookable               |       0       |
# | 70 |        calculated_host_listings_count        |       0       |
# | 71 | calculated_host_listings_count_entire_homes  |       0       |
# | 72 | calculated_host_listings_count_private_rooms |       0       |
# | 73 | calculated_host_listings_count_shared_rooms  |       0       |
# | 74 |              reviews_per_month               |     10352     |
# +----+----------------------------------------------+---------------+
